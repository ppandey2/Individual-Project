# %% [markdown]
# # USA’s unique gun violence problem -  Revision

# %% [markdown]
# ### Individual Project Revised Version

# %% [markdown]
# United States of America is a very huge country. It has vast space of land, mountains, sea, oceans around and along with nature it has man-made issues surrounding it as well. In this era, each and every country is constantly under the threat of nuclear attacks, war, and the whole world is facing gun violence issues. But not to forget, USA is one of the few countries in which the right to bear arms is constitutionally protected. The maps and charts presented in the Vox Article for "America’s unique gun violence problem, explained in 17 maps and charts" show that USA is among the top countries facing violence but I want to compare it with the rest of the world and give the conclusion a different angle. Though its a huge problem to fix but as USA so does other parts of the globe face the same situation. So, together, countries can join hands and get rid of this disasterous issue.

# %% [markdown]
# The libraries would be needed here are mentioned below. I used the below libraries for first version as well. I have used the  same datasets for First version, Redesign and the deceptive version.

# %%
#Important libraries to be imported before code execution
import pandas as pd
import numpy as np
import seaborn as sns
# %pylab inline
import sklearn as sk
import sklearn.tree as tree
from IPython.display import Image  
import pydotplus
import matplotlib.pyplot as plt
from plotly.offline  import download_plotlyjs,init_notebook_mode,plot, iplot
#Bokeh library imports
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral6
from bokeh.plotting import figure
from bokeh.layouts import layout
from bokeh.layouts import widgetbox
from bokeh.embed import file_html
from bokeh.io import output_notebook
from bokeh.models import Text
from bokeh.models import Plot
from bokeh.models import Slider
from bokeh.models import Circle
from bokeh.models import Range1d
from bokeh.models import CustomJS
from bokeh.models import HoverTool
from bokeh.models import LinearAxis
from bokeh.models import ColumnDataSource
from bokeh.models import SingleIntervalTicker

# testing
import unittest
import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Dataset description and sources

# %% [markdown]
# <ul>
# <li> <b> df</b> Mostly I have worked with dataset read as df which is from the source "unodc small arms survey via the guardian" about Gun violence in the USA. df is Dataviz_Graphs.csv a dataset of small arms survey data in the USA. Its Sources are:
# <dd> https://www.atf.gov/about/firearms-trace-data-2015 </dd></li>
# <li> <b> df1</b> is a dataset Statistical_Annex_Table.csv which contains the Human Development Index of the countries. I took the HDIfrom df1 and mapped it to the dataset df so as to rank countries according to that. It tells us which countries belong to the developed category.
# <p>Sources :</p>
# <dd> https://www.cdc.gov/nchs/pressroom/sosmap/firearm_mortality/firearm.htm </dd>
# <dd>https://www.atf.gov/about/firearms-trace-data-2015 </dd>
# <dd>https://ajph.aphapublications.org/doi/abs/10.2105/AJPH.2015.302749 </dd>
# <dd>https://data.world/azel/gun-deaths-in-america </dd>
# <dd>https://library.stanford.edu/projects/mass-shootings-america </dd>
# <dd>http://crowdsourcing-class.org/assignment9.html </dd>
# <dd>https://www.atf.gov/resource-center/docs/163524-alatfwebsite15pdf/download </dd>
# <dd>https://plot.ly/python/heatmaps/ </dd>
# <dd>http://www.smallarmssurvey.org/fileadmin/docs/A-Yearbook/2007/en/Small-Arms-Survey-2007-Chapter-02-annexe-4-EN.pdf.</dd>
# <dd>http://www.smallarmssurvey.org/fileadmin/docs/A-Yearbook/2007/en/Small-Arms-Survey-2007-Chapter-02-annexe-4-EN.pdf </dd>
# <dd>https://data.worldbank.org/indicator/SP.POP.TOTL </dd>
# <dd>https://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations) </dd>
# <b> <b></b> </ul>

# %% [markdown]
# # Graph 1

# %% [markdown]
# The very first graph in the Vox article Plot 1 looks like:

# %%
from IPython.display import Image
Image(filename='gun_homicides_developed_countries.jpg')

# %% [markdown]
# The first impression this graph makes is what are these numbers on top of the bars (man bars). Why are these man bars and not normal bars and why USA has 3 columns and others have 1. Is it due to the color, or due to the large number or it has some other hidden meaning. So, I decided to move ahead taking this as my first target to redesign.

# %% [markdown]
# ## Redesign for the above graph looked like this:

# %%
sns.factorplot(x='Country', y='% of homicides by firearm', data=dfslice, aspect=4, kind='bar')

# %% [markdown]
# The above chart shown by Vox article uses United Nations data to show that USA leads all the developed countries in the world in gun related homicides. They try to support their argument saying that this is true because "The US is an outlier on gun violence because it has way more guns than other developed nations." (Source: Statement from the Vox article). Before I knew about the fact of missing data, I was intrigued by the claim which the graph was showing us. It said that USA homicide rates are very high which is true but the graph did not make that much sense to me as I was not able to figure out how the numbers came in the big graph above.
# Also I was curious how they chose only this group of developed countries to support their claim. So, I wanted to dig deep into this very first plot.
# What interested me about this graph was that homicides rates across all countries for which data is available is quite low or under reported in many cases. There are issues of missing data and underreported information on homicides in many countries, the US homicide rate is less than the median rate and half of the mean for all countries. (Found out through deception analysis on the graph).
#
# Some issues that I found with the Redesigned Version were:
# 1. Its X-Axis and Y-axis were not labelled.
#
#     *Issue:* The graph did not explain the numbers 1,2,2,5 correctly. Someone can understand from the X-axis that it is showing country names but the numbers on Y-axis whithout a label does not make any sense.
#
#     *Remedy:* I tried to add axis-names and also tilt the country names a little so they fit into the space. I continued the use of a bar plot for the revision work also mostly because a bar plot shows the flow how the data is distributed country wise in the best possible way. If it were a map, then again it would have not been able to clearly explain the numbers. Bar-plots with their size, explain how big the hiomicide rate is in a country. I think it could have been also expressed using a pie-chart but with suppose top 5 developed countries. The issue would again be that the selection of countries gets limited.
#
# 2. The legends were not so clean.
#
#     *Issue:* The graph would never catch an eye if its look is not perfect. I think few more improvements can be done with this graph to improve look and feel though the essence will still remain the same.
#
#     *Remedy:* I can use tableau instead of sns plot to even get a better look and feel.
# 3. Bar plots could be made so they show the numbers as well as outliars on them.
#
#     *Issue:* The graph would never catch an eye if its look is not perfect. I think few more improvements can be done with this graph to improve look and feel though the essence will still remain the same.
#
#     *Remedy:* I need to gather more data so that outliar detection can be performed on this.

# %%
df = pd.read_csv('Dataviz_Graphs.csv')
df1 = pd.read_csv('Statistical_Annex_Table.csv')
#For easy access, changing column names
df1.rename(columns={'hdi1': 'hdi'}, inplace=True)
# drop empties
df = df.dropna()
df['HDI'] = ''

# %%
dfcopy = df1.copy()
dfdict = df1.set_index('Country')['hdi'].to_dict()
df['HDI'] = df['Country'].map(dfdict)
df.sort_values(by='HDI', ascending=0, inplace = True)
dfslice = df[0:19]

# %% [markdown]
# ## Revised Version of Graph 1

# %% [markdown]
# I revised the above graph using again a barplot only because as I explained, the information shown by the plot is intuitive. So, to improve look and feel, I changed the x-axis and y-axis labels.

# %%
g =sns.factorplot(x ='Country', y='% of homicides by firearm', 
                  data=dfslice, aspect=4, kind='bar', 
                  legend_out = True)
# replace labels
g.set_axis_labels("Countries", "Firearm Homicide Percentage")
g.set_titles("{col_name} {col_var}")
g.set_xticklabels(rotation=30)
sns.set_context("paper", rc={"font.size":26,"axes.titlesize":26,"axes.labelsize":12}) 
new_title = 'Country wise homicides by firearms'

# %%
Image(filename='compare1.png')

# %% [markdown]
# Why Redesign:
#     I added another graph using plotly package of python to obtain a better visualization. Here in this graph, I tried to add the axis names which were missing.
# Revision:
#     Revised version looks better than the redesign version.

# %% [markdown]
# # Graph 2:

# %% [markdown]
# Through this graph (Plot 3) the Vox article expresses the idea about the Mass Shootings in the USA based on the Sandy Hook case where an elementary school in Newtown, Connecticut, was targeted, in December 2012. The article emphasises that mass shootings have increased in the USA and they are severe, killing a lot of people. What drew my interest into this plot was mainly because of 3 issues/points which I thought were worth noticing:
#
# <li>It was a map showing mass shooting statistics using red dots where the color code did show the severity but the legend was missing. Also, statistics were not there in the graph. </li>
# <li>I was also interested in the statement the graph was making because they themselves mentioned that they do not have the complete statistics from all the states/counties so they agreed to the fact that some information/data might not be making complete sense.</li>
# <li>The exact definition of mass shooting was nowhere mentioned clearly. Though, it did mention that any act of killing/injury is considered as a mass shooting. They refute their own claim and again saying that mass shootings makes a very small portion of the gun deaths in the USA so I wanted to learn more about this.</li>

# %%
df2= pd.read_csv('Mass-shootings.csv')
df_firearm_by_state = pd.read_csv('Federal_Firearms_Licensees_by_State.csv')
df_firearm_by_state['FFL_Population'] = df_firearm_by_state['FFL_Population'].str.replace(',', '')
df_firearm_by_state['FFL_Population'] = df_firearm_by_state['FFL_Population'].astype(int)

# %%
#Adding a column Percent and calculating % of firearm deaths.
df2['total_shootings'] = df2.sum(axis=1)
sumshoot = df2['total_shootings'].sum()
df2.sort_values(by='total_shootings', ascending=0, inplace = True)
df2['percent']= ''
df2['percent'] = (df2.total_shootings/sumshoot)*100
df2.sort_values(by='percent', ascending=0, inplace = True)

# %%
dfdict1 = df_firearm_by_state.set_index('State')['FFL_Population'].to_dict()
df2['Firearm_possessed'] = df2['State'].map(dfdict1)

# %%
edited_mass_shootings = df2.to_csv('edited_mass_shootings.csv')

# %%
dfshoot = df2[0:30]

# %% [markdown]
# ## Revision work:

# %% [markdown]
# Here when I try to find the regression of total shootings and firearm possession this is the outcome. I have outliars here.

# %%
plt=sns.regplot(x='total_shootings', y='Firearm_possessed', data=dfrangemodified)
plt.set(ylim=(-500, 15000))
# Out:
# [(-500, 15000)]

# %% [markdown]
# I can see from the above graph that because of lack of proper gun possession records and mass shootings data, it kind of says that states where there are less guns see mass shootings on a large scale and vice versa. There are outliars in the dataset , here Nevada, as we see in the above redesign as well which shows that the mass shooting in that place is in large number and exceedingly more than any other state.  Thus it needs a revision.

# %% [markdown]
# Some issues that I found with the Redesigned Version were:
# 1. It was showing the outliar information as a huge big bar plot and rest of the state data were small.
#
#     *Issue:* It was making the look and feel deceptive as well as biased.
#
#     *Remedy:* I tried to show the Mass shootings (Total Shootings) and the loss of life that happened in them together. So, from that solution I could see that as Vox defines a mass shooting as "injured and killed", we can clearly see that if a place had a mass shooting, the rate of killed andinjured were half the mass shooting number. This means that they have just made their decision based on some huge mass shootings that has happened in the country in the recent period (around 2012) and thus made a general conclusion based on the Sandy Hook incident.
#
#     I would not deny with the fact that there has been mass shootings and lives were lost in the USA which was a concern for the country but where and why and how cannot be explained by just the data source available. A lot of factors contribute to that.
#
# 2. The redesign graph was showing the places with a major focus on Nevada. But I could see after the revision work that due to lack of proper data, Nevada is an outliar which is showing a high number.
#
#     *Issue:* Graph was having lack of information and was misleading in a way.
#
#     *Remedy:* I then changed the orientation of the graph. Though it is not a very great idea but I assume sometimes looks are deceptive and make us conclude what we actually don't want to believe. After changing the orientation, I could actually see that earlier the states that looked to have quite less loss of lives and shooting statistics, were actually having quite big amount of death count.
#
# 3. The redesign graph also had a line chart which replicated the same information and in a non intuitive manner. I assume it was not required for the redesigning as both the bar and line chart said the same information.
#
#     *Issue:* Repeatative information.
#
#     *Remedy:* I just kept the bar chart and then improved the same using tableau.

# %%
Image('compare2.png')

# %% [markdown]
# Link to Tableau Public: Resign Graph 2:
#     https://public.tableau.com/profile/priyanka6762#!/vizhome/Revision_3/MassShootingsintheUSAshowingtotallossoflives?publish=yes

# %% [markdown]
# # Graph 3

# %%
Image(filename='plot3.png')

# %%
from plotly.offline import init_notebook_mode, iplot
#from wordcloud import WordCloud
import matplotlib.pyplot as plt
import plotly.graph_objs as go
#from wordcloud import WordCloud
#from textblob import TextBlob 

import plotly.plotly as py
from plotly import tools
import seaborn as sns
import pandas as pd
import string, os, random
import calendar

init_notebook_mode(connected=True)
punc = string.punctuation
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
df2= pd.read_csv('Mass-shootings.csv', parse_dates = ['Incident Date'])
df2['year'] = df2['Incident Date'].dt.year
df2['loss'] = df2['# Killed'] + df2['# Injured']

# %%
statdf = df2.reset_index().groupby(by=['State']).agg({'loss':'sum', 'year':'count'}).rename(columns={'year':'count'})
statdf['State'] = statdf.index

trace1 = go.Bar(
    x=statdf['State'],
    y=statdf['count'],
    name='Count of Incidents',
    marker=dict(color='rgb(255,10,225)'),
    opacity=0.6
)
trace2 = go.Bar(
    x=statdf['State'],
    y=statdf['loss'],
    name='Total Deaths/Loss',
    marker=dict(color='rgb(58,22,225)'),
    opacity=0.6
)

data = [trace1, trace2]
layout = go.Layout(
    barmode='group',
    legend=dict(dict(x=-.1, y=1.2)),
    title = 'Number of Gun Violence Incidents and Total Deaths/Life loss in USA',
    xaxis=dict(
        title='USA County',
        titlefont=dict(
            family='Arial, sans-serif',
            size=18,
            color='lightgrey'
        ),
        showticklabels=True,
        tickangle=30,
        tickfont=dict(
            family='Old Standard TT, serif',
            size=12,
            color='black'
        ),
        exponentformat='e',
        showexponent='All'
    ),
    yaxis=dict(
        title='Total Deaths',
        titlefont=dict(
            family='Arial, sans-serif',
            size=18,
            color='lightgrey'
        ),
        showticklabels=True,
        tickangle=0,
        tickfont=dict(
            family='Old Standard TT, serif',
            size=14,
            color='black'
        ),
        exponentformat='e',
        showexponent='All'
    )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='axes-labels')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ppandey2/14.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Revised Version

# %% [markdown]
# Some issues that I found with the Redesigned Version were:
# 1. It was showing the some places as blank which was due to lack of proper dataset.
#
#     *Issue:* It was making the look and feel deceptive as well as biased.
#
#     *Remedy:* I tried to show the Mass shootings (Total Shootings) and the loss of life that happened in them together. So, from that solution I could see that as Vox defines a mass shooting as "injured and killed", and loss of lives has been increasing. So, for Nevada the possession of gun is small but gun deaths are huge. This is an outliar. Also, we see that there are many places which have a high amount of gun possessions but gun violence incidents say something else there.
#
#     I would not deny with the fact that there has been mass shootings and lives were lost in the USA which was a concern for the country but where and why and how cannot be explained by just the data source available. A lot of factors contribute to that.
#
# 2. The redesign graph missing legends.
#
#     *Issue:* Graph was having lack of information and was misleading in a way, it does not look good.
#
#     *Remedy:* I then changed the orientation of the graph. Other plots also did not make much sense to me here. I initially added a map for this one but then a map essentially doe not express the correct information so I removed it. And thus for me the best option I found was a bar plot.
#
# 3. The redesign graph also had a line chart which replicated the same information.
#
#     *Issue:* Repeatative information.
#
#     *Remedy:* I just kept the bar chart and then improved the same using plotly package.

# %%
Image(filename='compare3.png')

# %% [markdown]
# # Deceptive Version of Graph 1

# %% [markdown]
# ### Data preparation steps for Deceptive Version: Plot 1:

# %% [markdown]
# What we learnt in the class is to decide which plot to use we should compare , contrast and then see the difference. We should bring multiple data points to analyze and interpret. Also, refined data should be used. What I found was that the claim made by first graph held true even after I redesigned the graph with the rate of firearm homicides.
#
# But, when I used total number of firarms homicide and then tried to compare it with all the states, I found that there are a lot many countries which belong to the category of developed countries still they are missing from the data. As well as, countries list which can be used to see this is almost 192 in total and we have taken so small a group and made our conclusion based on it.
# Here we don't deal with criminal data but if considered, it will tell the criminal cases all over the world and how USA is nowhere near to that. So, this makes us think as to why USA has this issue of homicide and is it really that big?
#
# The dataset Dataviz_Graphs.csv file contains USA Country wise data showing Homicide rates, firearms possession counts and himicide details like firearm per 100 population, % of homicides by firearms and total civilian firearms.

# %%
df['% of homicides by firearm'].mean()
# Out:
# 31.820560747663553

# %% [markdown]
# A few basic insights from the data that is made available showing that homicide rate in the USA is super high and beyond expectations.

# %% [raw]
# Mean of firearm homicide rate among all countries:

# %%
df['Homicide by firearm rate per 100,000 pop'].mean()
# Out:
# 4.678224299065421

# %%
df['Homicide by firearm rate per 100,000 pop'].median()
# Out:
# 0.48

# %% [markdown]
# Homicide in the USA:

# %%
df.loc[176]
# Out:
# Country                                     United States
# ISO code                                               US
# Source                                                CTS
# % of homicides by firearm                              60
# Number of homicides by firearm                       9146
# Homicide by firearm rate per 100,000 pop             2.97
# Rank by rate of ownership                               1
# Average firearms per 100 people                      88.8
# Average total all civilian firearms               2.7e+08
# Population_per_thousand                           182.273
# HDI                                                  0.92
# Name: 176, dtype: object

# %% [markdown]
# We can clearly see here that homicides rates across all countries for which data is available. There are issues of missing data and underreported information on homicides in many countries, the US homicide rate is less than the median rate and half of the mean for all countries. My deceptive version of the graph emphesises on this point.
#
# The vox article claims that Claim “America has six times as many firearm homicides as Canada, and nearly 16 times as many as Germany”. There is no explanation for why they compare only these 14 countries. There are a lot of developed countries which fall into this category and have potential homicides going on in there and even more. I found a related article here : http://www.oecdbetterlifeindex.org/topics/safety/. Also, there are 192 countries for which homicide data is available. So, now I want to express the deception hidden in this graph.

# %%
# drop empties
df = df.dropna()
#Adding an empty column HDI to df dataset to be used with df1.
df['HDI'] = ''
df1 = pd.read_csv('Statistical_Annex_Table.csv')
#For easy access, changing column names
df1.rename(columns={'hdi1': 'hdi'}, inplace=True)
dfcopy = df1.copy()
dfdict = df1.set_index('Country')['hdi'].to_dict()
df['HDI'] = df['Country'].map(dfdict)
df.sort_values(by='HDI', ascending=0, inplace = True)
dfslice = df[0:19]

# %% [markdown]
# The dataset Statistical_Annex_Table.csv file contains the Country wise data showing Life expectancy rates, Income per capita. #Adding the HDI ; Human Development Index column to the data for getting the list of developed countries. Added the newly created HDI numbers to the dataset df using the dictionary of HDI numbers from df1. #Taking just the 20 countries which have highest HDI value; Human Development Index tells us which country belongs to the list of developed country.

# %% [markdown]
# We can clearly see here that homicides rates across all countries for which data is available. There are issues of missing data and underreported information on homicides in many countries, the US homicide rate is less than the median rate and half of the mean for all countries.
# Looking at the below graph we can infer that many countries does not report the homicides and USA is quite low compared to many countries as seen in the list.

# %% [markdown]
# Tableau Public: https://public.tableau.com/profile/priyanka6762#!/vizhome/IndividualProject-USAsGunViolenceProblem/Deceptive3?publish=yes
#
# Tableau self account: https://us-west-2b.online.tableau.com/#/site/tableauforvisualizationgunviolence/workbooks/33409/views

# %% [markdown]
# ## Revised version of Deceptive Graph 1

# %%
from IPython.display import Image
Image(filename='Compare_deceptive_version_1.png')

# %% [markdown]
# The USA homicide rate is high, though the most important question here is how homicide rates vary with gun ownership. Vox doesn’t deal with this. So, other than gun ownership, several factors might contribute to it. And, some countries have super huge homicide rates than USA which are ignored by the article. Probably to focus on an issue and make it eye catchy, the method is adopted. But a duty of a graph is to first render a clear and correct information than exagerated information.

# %% [markdown]
# Process followed:

# %% [markdown]
# Some issues that I found with the Redesigned Version were:
#
# 1. The USA homicide rate is high, though the most important question here is how homicide rates vary with gun ownership.
#
#     *Issue:* It was making the look and feel deceptive as well as biased.
#
#     *Remedy:* So, here as a first step what I have done is I downloaded the dataset from CDC and Small Arms Survey site (Link provided in the data description part above) and tried to see Guns vs the homicides and tried going through some articles related to that. I found out that here at this point, some countries have been missed which whould make the data and information rendered by the chart different or I should say, less severe. So, as a next step: I create a new book in tableau, select Text file and upload my dataset which is on Gun homicides and firearm possessions "Dataviz_graphs". Now I read in the Country and firearm hiomicide rates and firearm possession rates. I try to see homicide by firarms country wise and see that though USA has a huge rate of firearm homicides still there are countries which have the number even bigger (Honduras). So, I try to add the labels to the bars to show the exact number I did that by selecting "Show labels". Also I added Country as  filter to just filter out some countries which are ranked as developed countries by Human Development Index official site information.
#
#    I have used a bar plot to show this because I thought it works best with the dataset. Also, some data were missing so it would makeup for that.
#
# 2. The redesign graph had misleading legends.
#
#     *Issue:* Graph was having lack of information and was misleading in a way, it does not look good.
#
#     *Remedy:* I then changed the orientation of the graph. Other plots also did not make much sense to me here. And thus for me the best option I found was a bar plot. Chnaged the legend names.

# %% [markdown]
# # Deceptive Graph 2

# %% [markdown]
# Vox posted an analysis showing that more guns lead to more gun deaths as shown below.  <li>The graph which I have used to find a deceptive version is Vox Article Graph 6. (Refer image below)</li>

# %%
Image(filename='Deceptive_graph_vox_2.png')

# %% [markdown]
# The above vox article claims that more guns contribute to more gun deaths. But I want to argue that there is deception hidden here and even though more guns contribute to more gun deaths, gun availability isn’t the only thing that leads to gun deaths.
#
# Other factors also play a major role in this. I can argue based on the fact that if it was true, the USA would have the highest homicide rate in the world because the USA has by far the most guns per capita. I wonder the choice of countries that has been made plays all the cards here. I kind of could not figure out any simple rule that explains how they picked these countries in the above graph. Maybe the list of countries has been considered based on the source : http://www.oecd.org/about/membersandpartners/.
#
# Also,  it should really include Panama and Uruguay which are richer than Argentina (which is included).
#
# Also it is evident that gun availability is actually somewhat correlated with fewer gun deaths. I tried excluding all nations poorer than Spain, but it still doesn’t give much support to the thesis that more guns cause more homicides because there is little correlation again.
# Data Source: “Estimating Civilian Owned Firearms”
#
# Basically, these are outliers, they should both probably be excluded. But again there is almost zero correlation between guns and homicides. That doesn’t mean that guns don’t contribute to the high homicide rate in the USA, but it just isn’t just that. Lots of other factors are also important such as environmental lead, criminal justice, inequality which are responsible for which data shgould be made available to come to a conclusion like this. Thus, just changing the list gives us altogether a different insight which I think is a deception.
#
# Ref: http://www.nationmaster.com/country-info/stats/Crime/Violent-crime/Gun-crime/Guns-per-100-residents

# %% [markdown]
# ## Revised Version Deceptive Graph 2

# %%
Image(filename='Compare_deceptive_version_2.png')

# %% [markdown]
# ### Making of :

# %% [markdown]
# <ol>
#   <li>I have used used Tableau to recreate and come up with the revised version of the Graph 2 deceptive model.</li>
#   <p>So, here as a first step what I have done is I downloaded the dataset from CDC and Small Arms Survey site (Link provided in the data description part above) and tried to see Guns vs the homicides and tried going through some articles related to that.
#   </p>
#
#   <li>So, as a next step: I create a new book in tableau, select Text file and upload my dataset which is on Gun homicides and firearm possessions "Dataviz_graphs".</li>
#   <li> Now I read in the Country and firearm hiomicide rates and firearm possession rates for rich countries. I try to see homicide by firarms country wise and see that though USA has a huge rate of firearm homicides when I scale them based on total number of firearms (I add Column "Number of homicides by Firearms" to Size field)and then I see that USA has a big number in it and when I treat the column "Number of homicides by Firearms" and treat it with Gautemala and other countries, USA's homicide rate shows a less number </li>
#   <li>So that explains my argument.</li>
#   <li>Again I try to show it in a next sheet "Homicides in Richer Countries - Deceptive 2" so I can see the trend again.</li>
#
# </ol>
# Some issues that I found with the Redesigned Version were:
#
# 1. The outliar in the dataset has such a big size that only USA is visible in the graph.
#
#     *Issue:* It was making the look and feel deceptive as well as biased.
#
#     *Remedy:* I read in the Country and firearm hiomicide rates and firearm possession rates for rich countries. I try to see homicide by firarms country wise and see that though USA has a huge rate of firearm homicides when I scale them based on total number of firearms (I add Column "Number of homicides by Firearms" to Size field)and then I see that USA has a big number in it and when I treat the column "Number of homicides by Firearms" and treat it with Gautemala and other countries, USA's homicide rate shows a less number. Thus, now I see how places such as El Salvador, Israel are making a difference there. earlier thet were not visible due to the scatter plot.
#
#    I used scatter plot to show this earlier because I thought it works best with the dataset and the size of hue values could be easliy shown there. But then I tried bar plot with comparison and it works better for me
#
# 2. The redesign graph had misleading legends.
#
#     *Issue:* Graph was having lack of information and was misleading in a way, it does not look good.
#
#     *Remedy:* I then changed the orientation of the graph. Other plots also did not make much sense to me here. And thus for me the best option I found was a bar plot. Chnaged the legend names.

# %% [markdown]
# ### Revision Deceptive 2 graph:

# %% [markdown]
# The Vox article expresses the idea about the Mass Shootings in the USA based on the Sandy Hook case where an elementary school in Newtown, Connecticut, was targeted, in December 2012. The article emphasises that mass shootings have increased in the USA and they are severe, killing a lot of people. What drew my interest into this plot was mainly because of 3 issues/points which I thought were worth noticing:
#
# <li>I applied reverse technique as we use in Visualization when we know what claim a graph has to make and we have our reverse argument ready for the case. So, in that case, a visualization is used to validae our claim. Here the Vox article shows the guns and guns related deaths. There USA has outnumbered many countries. But, the interesting point is </li>
# <li>I was also interested in the statement the graph was making because they themselves mentioned that they do not have the complete statistics from all the states/counties so they agreed to the fact that some information/data might not be making complete sense.</li>
# <li>The exact definition of mass shooting was nowhere mentioned clearly. Though, it did mention that any act of killing/injury is considered as a mass shooting. They refute their own claim and again saying that mass shootings makes a very small portion of the gun deaths in the USA so I wanted to learn more about this.</li>

# %% [markdown]
# # Deceptive Graph 3

# %%
from IPython.display import Image
Image(filename='vox_3.png')

# %% [markdown]
# The Vox article mentions that  “America has 4.4 percent of the world’s population, but almost half of the civilian-owned guns around the world”, I have tried to measure world population and the distribution of firearms in the country and the USA. First of all, there is a huge difference hidden in the meaning of the terms, civilian-possessed guns than civilian-owned guns. Countries such as Israel, Switzerland have a lot more civilian-possessed guns than civilian-owned guns. Also, the deceptive version of the graph (below) shows the population distribution and the possession of arms. So, countries such as Cyprus for instance, has a population similar to Switzerland and its ranking in Gun possession is 6th. But, its average firearms ownership is so low. Which means they have to reconsider the variables "Average total firearms", "Civilian-possessed", "civilian-owned guns" to show a clear distribution. So, I assume they have even the gun possession rate higher than the gun ownership rate in the USA.  But there is a bigger accuracy problem in counting gun ownership using surveys or gun registration.  There is strong evidence that most guns are never registered.
#
# There has been studies which says there are issues relted to gun possession and actual registration. Source: https://www.independent.co.uk/news/world/politics/switzerland-high-rates-gun-ownership-why-doesnt-no-mass-shootings-a8230606.html . Example: When Canada tried to register its estimated 15 million to 20 million long guns during the late 1990s, about 7 million were registered.
#
# Even in the US, there is evidence that surveys of gun ownership rates are not very accurate.  In many countries where gun ownership is illegal, surveys continually show zero gun ownership even when that is clearly not the case.
#
# The bottom line is that the numbers of guns in the rest of the world is underestimated relative to the number in the United States.  So 42% is likely a huge overestimate of the US’s true share of guns worldwide which for me is deceptive in nature.

# %%
Image(filename='Compare_deceptive_version_3.png')

# %% [markdown]
# Showing Cyprus and Switzerland. The distribution says a lot about how the population and average firearm possession are some what not correct and potential causes of deception.

# %% [markdown]
# Tableau Public: https://public.tableau.com/profile/priyanka6762#!/vizhome/IndividualProject-USAsGunViolenceProblem/RevisionDec-3?publish=yes

# %% [markdown]
# ### Making of - Process in Tableau:

# %% [markdown]
# <ol>
#   <li>I have used Tableau to recreate the Graph 3 deceptive model.</li>
#   <li>The graph which I have used to find a deceptive version is Vox Article Graph 2.</li>
#
#   <li>So, here as a first step what I have done is I downloaded the dataset from CDC and Small Arms Survey site (Link provided in the data description part above) and tried to see Guns vs the homicides and tried going through some articles related to that.</li>
#   <p>I found out that here at this point, I have world population data missing in the table which I would need to prove my point.
#   I have tried to get world population data from wikipedia , Source : http://www.smallarmssurvey.org/fileadmin/docs/A-Yearbook/2007/en/Small-Arms-Survey-2007-Chapter-02-annexe-4-EN.pdf , https://data.worldbank.org/indicator/SP.POP.TOTL, https://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations) </p>
#
#
#   <li>So, as a next step: I create a new book in tableau, select Text file and upload my dataset which is on Gun homicides and firearm possessions "Dataviz_graphs".</li>
#   <li> Now I tried to add population data and use that to make the Sheet :Deceptive 3 Graph. Also, here I try to show my argument by doing a highlight to the Country I want to focus. So, for that I created a legend which says if it is , for instance, USA, then its color is orange and is True and if it is not, its color is blue and value is False.
#   </li>
#   <li>I try to show how a country has a variation in population and how possession of total firearms depends/varies with that. I have made my argument based on this information. Even after that I could see the claim which I provide above. So that explains my argument.</li>
#   <li>Again I try to show it in a next sheet "Deceptive 3 - Total pop"  which means total population wise how aI am trying to compare the same information. so I can see the trend again. I observe that some countries are big outliars and that can be because of missing data. Also, Australia, Switzerland they are quite close to USA but maybe beacuse of some laws or maybe other reasons, probably, the information is not correct. Also, time trend may vary the insight as suggested by the article: https://www.independent.co.uk/news/world/politics/switzerland-high-rates-gun-ownership-why-doesnt-no-mass-shootings-a8230606.html . </li>
# <li>Thus I think it is a deceptive version of the graph exagerating the fact to the viewers. I have used a scatter plot for the same</li>
# </ol>

# %% [markdown]
# Some issues that I found with the Redesigned Version were:
#
# 1. The outliar in the dataset has such a big size that only USA is visible in the graph.
#
#     *Issue:* It was making the look and feel deceptive as well as biased.
#
#     *Remedy:* I changed the scatter plot to box plot. Added colors to all countries and filtered the countries showing limited number of them  Average firearm per 100 people. So, it made the graph look even better than before.
#
#    I used scatter plot to show this earlier because I thought it works best with the dataset and the size of hue values could be easliy shown there. But then I tried bar plot with comparison and it works better for me.
#
# 2. The redesign graph had misleading legends.
#
#     *Issue:* Graph was having lack of information and was misleading in a way, it does not look good.
#
#     *Remedy:* I then changed the orientation of the graph. Other plots also did not make much sense to me here. And thus for me the best option I found was a bar plot. Chnaged the legend names.

# %% [markdown]
# Here is the link to Tableau public:
# https://public.tableau.com/profile/priyanka6762#!/vizhome/Revision_3/MassShootingsintheUSAshowingtotallossoflives?publish=yes

# %% [markdown]
# #### Conclusion

# %% [markdown]
# I have specifically chosen different graphs and tried to show how well they can be represented using different graphing techniques. Apart from that sometimes it is possible that a visualization does not come out that great because of scaling issues, outliar issues and data missing issues. I have tried to address such issues as well here through this exercise. I would assume that the visualizations expressed here are perfect but I would not forget to metion that there is always a scope for improvement which comes through sound research and understanding of target audience, relevance of data and correct sources, mechanism applied and through the technique of compare and contrast.
